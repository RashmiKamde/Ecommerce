# %% [markdown]
# <a href="https://colab.research.google.com/github/RashmiKamde/Ecommerce/blob/main/E_commerce.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import files
data = files.upload()
data = files.upload()
# Out:
#      <input type="file" id="files-af83fb4e-3280-40fb-895c-db4bf3ad643d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-af83fb4e-3280-40fb-895c-db4bf3ad643d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data = files.upload()
data = files.upload()
# Out:
#      <input type="file" id="files-6b1d6d1d-eaee-4295-a615-7c15ced43f35" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6b1d6d1d-eaee-4295-a615-7c15ced43f35">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
customers_df = pd.read_csv("/content/Customers.csv")
ecommerce_df = pd.read_csv("/content/Ecommerce.csv")
orders_df = pd.read_csv("/content/Orders.csv")
product_df = pd.read_csv("/content/Products.csv")

# %%
customers_df.shape
# Out:
# (10000, 10)

# %%
ecommerce_df.shape
# Out:
# (50000, 11)

# %%
orders_df.shape
# Out:
# (50000, 9)

# %%
product_df.shape
# Out:
# (25, 10)

# %% [markdown]
# #Customers dataset

# %%
customers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Customer ID     10000 non-null  object
#  1   Customer Name   10000 non-null  object
#  2   Email           10000 non-null  object
#  3   Phone Number    10000 non-null  int64
#  4   Address         10000 non-null  object
#  5   City            10000 non-null  object
#  6   State           10000 non-null  object
#  7   Country         10000 non-null  object
#  8   Signup Date     10000 non-null  object
#  9   Loyalty Status  10000 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 781.4+ KB

# %%
customers_df.isna().sum()
# Out:
# Customer ID       0
# Customer Name     0
# Email             0
# Phone Number      0
# Address           0
# City              0
# State             0
# Country           0
# Signup Date       0
# Loyalty Status    0
# dtype: int64

# %%
customers_df.duplicated().sum()
# Out:
# 0

# %%
customers_df.columns
# Out:
# Index(['Customer ID', 'Customer Name', 'Email', 'Phone Number', 'Address',
#        'City', 'State', 'Country', 'Signup Date', 'Loyalty Status'],
#       dtype='object')

# %%
customers_df.head()
# Out:
#   Customer ID    Customer Name              Email  Phone Number  \
# 0    CUST1000        Priya Das  user0@example.com    9777846666
# 1    CUST1001  Divya Choudhary  user1@example.com    9417858370
# 2    CUST1002      Neha Sharma  user2@example.com    9719294462
# 3    CUST1003       Neha Reddy  user3@example.com    9954768147
# 4    CUST1004      Sneha Kumar  user4@example.com    9444506592
#
#                  Address       City        State Country Signup Date  \
# 0    108, Kolkata Street    Chennai        Delhi   India  2023-06-04
# 1  801, Bangalore Street  Ahmedabad   Tamil Nadu   India  2023-09-12
# 2       808, Pune Street     Mumbai    Karnataka   India  2020-03-31
# 3    483, Kolkata Street       Pune   Tamil Nadu   India  2021-06-13
# 4    919, Chennai Street      Delhi  Maharashtra   India  2022-10-18
#
#   Loyalty Status
# 0           Gold
# 1         Silver
# 2           Gold
# 3           Gold
# 4       Platinum

# %%
customers_df["Email"] = customers_df["Customer Name"].str.lower().str.replace(" ","")+"@gmail.com"

# %%
customers_df.head(5)
# Out:
#   Customer ID    Customer Name                     Email  Phone Number  \
# 0    CUST1000        Priya Das        priyadas@gmail.com    9777846666
# 1    CUST1001  Divya Choudhary  divyachoudhary@gmail.com    9417858370
# 2    CUST1002      Neha Sharma      nehasharma@gmail.com    9719294462
# 3    CUST1003       Neha Reddy       nehareddy@gmail.com    9954768147
# 4    CUST1004      Sneha Kumar      snehakumar@gmail.com    9444506592
#
#                  Address       City        State Country Signup Date  \
# 0    108, Kolkata Street    Chennai        Delhi   India  2023-06-04
# 1  801, Bangalore Street  Ahmedabad   Tamil Nadu   India  2023-09-12
# 2       808, Pune Street     Mumbai    Karnataka   India  2020-03-31
# 3    483, Kolkata Street       Pune   Tamil Nadu   India  2021-06-13
# 4    919, Chennai Street      Delhi  Maharashtra   India  2022-10-18
#
#   Loyalty Status
# 0           Gold
# 1         Silver
# 2           Gold
# 3           Gold
# 4       Platinum

# %% [markdown]
# #Ecommerce dataset

# %%
ecommerce_df.head(6)
# Out:
#     Order ID Customer ID  Product Name        Category  Quantity  Price  \
# 0  ORD100000    CUST5897      Lipstick          Beauty         4    948
# 1  ORD100001    CUST4545    Smartwatch     Electronics         3  16971
# 2  ORD100002    CUST2774  Cookware Set  Home & Kitchen         1   4263
# 3  ORD100003    CUST7307        Laptop     Electronics         5  11461
# 4  ORD100004    CUST9897        Laptop     Electronics         5  40083
# 5  ORD100005    CUST7405      Lipstick          Beauty         5   2435
#
#    Discount  Order Date Shipping Date    Payment Method Delivery Status
# 0      0.15  2023-03-30    2023-04-06       Credit Card      Processing
# 1      0.19  2023-02-09    2023-02-11  Cash on Delivery       Delivered
# 2      0.27  2023-08-20    2023-08-27  Cash on Delivery         Shipped
# 3      0.18  2023-08-28    2023-09-02  Cash on Delivery       Delivered
# 4      0.29  2023-07-19    2023-07-25  Cash on Delivery       Cancelled
# ...

# %%
ecommerce_df.isnull().sum()
# Out:
# Order ID           0
# Customer ID        0
# Product Name       0
# Category           0
# Quantity           0
# Price              0
# Discount           0
# Order Date         0
# Shipping Date      0
# Payment Method     0
# Delivery Status    0
# dtype: int64

# %%
ecommerce_df.duplicated().sum()
# Out:
# 0

# %%
ecommerce_df.describe()
# Out:
#            Quantity         Price      Discount
# count  50000.000000  50000.000000  50000.000000
# mean       2.998540   7781.807060      0.174423
# std        1.411856  11625.014124      0.074694
# min        1.000000    500.000000      0.050000
# 25%        2.000000   1901.000000      0.110000
# 50%        3.000000   3327.000000      0.170000
# 75%        4.000000   4725.000000      0.240000
# max        5.000000  49999.000000      0.300000

# %% [markdown]
# #Orders dataset

# %%
orders_df.head()
# Out:
#     Order ID Customer ID  Product Name  Quantity  Order Date Shipping Date  \
# 0  ORD100000    CUST5897      Lipstick         4  2023-03-30    2023-04-06
# 1  ORD100001    CUST4545    Smartwatch         3  2023-02-09    2023-02-11
# 2  ORD100002    CUST2774  Cookware Set         1  2023-08-20    2023-08-27
# 3  ORD100003    CUST7307        Laptop         5  2023-08-28    2023-09-02
# 4  ORD100004    CUST9897        Laptop         5  2023-07-19    2023-07-25
#
#      Payment Method Order Status  Total Amount
# 0       Credit Card   Processing       3223.20
# 1  Cash on Delivery    Delivered      41239.53
# 2  Cash on Delivery      Shipped       3111.99
# 3  Cash on Delivery    Delivered      46990.10
# 4  Cash on Delivery    Cancelled     142294.65

# %%
orders_df['Total Amount'] = np.round(orders_df['Total Amount'],2)

# %%
orders_df.head()
# Out:
#     Order ID Customer ID  Product Name  Quantity  Order Date Shipping Date  \
# 0  ORD100000    CUST5897      Lipstick         4  2023-03-30    2023-04-06
# 1  ORD100001    CUST4545    Smartwatch         3  2023-02-09    2023-02-11
# 2  ORD100002    CUST2774  Cookware Set         1  2023-08-20    2023-08-27
# 3  ORD100003    CUST7307        Laptop         5  2023-08-28    2023-09-02
# 4  ORD100004    CUST9897        Laptop         5  2023-07-19    2023-07-25
#
#      Payment Method Order Status  Total Amount
# 0       Credit Card   Processing       3223.20
# 1  Cash on Delivery    Delivered      41239.53
# 2  Cash on Delivery      Shipped       3111.99
# 3  Cash on Delivery    Delivered      46990.10
# 4  Cash on Delivery    Cancelled     142294.65

# %%
orders_df.describe()
# Out:
#            Quantity   Total Amount
# count  50000.000000   50000.000000
# mean       2.998540   19320.200698
# std        1.411856   33410.653996
# min        1.000000     355.000000
# 25%        2.000000    3419.955000
# 50%        3.000000    7352.750000
# 75%        4.000000   14877.775000
# max        5.000000  235058.500000

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        50000 non-null  object
#  1   Customer ID     50000 non-null  object
#  2   Product Name    50000 non-null  object
#  3   Quantity        50000 non-null  int64
#  4   Order Date      50000 non-null  object
#  5   Shipping Date   50000 non-null  object
#  6   Payment Method  50000 non-null  object
#  7   Order Status    50000 non-null  object
#  8   Total Amount    50000 non-null  float64
# dtypes: float64(1), int64(1), object(7)
# memory usage: 3.4+ MB

# %%
orders_df.isna().sum()
# Out:
# Order ID          0
# Customer ID       0
# Product Name      0
# Quantity          0
# Order Date        0
# Shipping Date     0
# Payment Method    0
# Order Status      0
# Total Amount      0
# dtype: int64

# %%
orders_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #Produc dataset

# %%
product_df.head()
# Out:
#   Product ID    Product Name        Category   Brand             Supplier  \
# 0   PROD1000        Sneakers         Fashion  Adidas     XYZ Distributors
# 1   PROD1001        Yoga Mat          Sports    Sony  FastTrack Logistics
# 2   PROD1002  Vacuum Cleaner  Home & Kitchen  Adidas  FastTrack Logistics
# 3   PROD1003         Perfume         Fashion      LG     XYZ Distributors
# 4   PROD1004         T-Shirt         Fashion  Adidas      Global Supplies
#
#    Stock Quantity  Cost Price  Selling Price  Ratings (Avg.) Launch Date
# 0             317        3095           2474             4.5  2023-09-21
# 1             327        3850           3555             3.6  2021-07-19
# 2             179        3818           3526             3.3  2023-11-10
# 3             390        2393           3546             3.7  2021-07-10
# 4             191         854           1102             4.0  2023-12-27

# %%
product_df.describe()
# Out:
#        Stock Quantity  Cost Price  Selling Price  Ratings (Avg.)
# count       25.000000    25.00000      25.000000        25.00000
# mean       293.200000  2353.60000    2459.680000         3.94400
# std        115.025722  1286.91838    1223.042167         0.54626
# min        106.000000   301.00000     527.000000         3.10000
# 25%        200.000000  1290.00000    1203.000000         3.60000
# 50%        278.000000  2230.00000    2474.000000         4.00000
# 75%        390.000000  3810.00000    3546.000000         4.20000
# max        500.000000  3959.00000    4022.000000         5.00000

# %%
product_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Product ID      25 non-null     object
#  1   Product Name    25 non-null     object
#  2   Category        25 non-null     object
#  3   Brand           25 non-null     object
#  4   Supplier        25 non-null     object
#  5   Stock Quantity  25 non-null     int64
#  6   Cost Price      25 non-null     int64
#  7   Selling Price   25 non-null     int64
#  8   Ratings (Avg.)  25 non-null     float64
#  9   Launch Date     25 non-null     object
# dtypes: float64(1), int64(3), object(6)
# memory usage: 2.1+ KB

# %%
product_df.isna().sum()
# Out:
# Product ID        0
# Product Name      0
# Category          0
# Brand             0
# Supplier          0
# Stock Quantity    0
# Cost Price        0
# Selling Price     0
# Ratings (Avg.)    0
# Launch Date       0
# dtype: int64

# %%
product_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Download cleaned datset as excel or csv file

# %%
# !pip install pyodbc sqlalchemy pandas

# %%
import pandas as pd
import pyodbc
from sqlalchemy import create_engine

# %%
customers_df.to_csv("customers.csv", index=False)
ecommerce_df.to_csv("ecommerce.csv", index=False)
orders_df.to_csv("orders.csv", index=False)
product_df.to_csv("products.csv", index=False)
print("\u2705 Data saved successfully as CSV!")
# Out:
# ✅ Data saved successfully as CSV!

# %% [markdown]
# # Download csv file in local system

# %%
files.download("customers.csv")
files.download("ecommerce.csv")
files.download("orders.csv")
files.download("products.csv")

# %%
with pd.ExcelWriter("cleaned_ecommerce_data.xlsx") as writer:
    customers_df.to_excel(writer, sheet_name="Customers", index=False)
    ecommerce_df.to_excel(writer, sheet_name="Ecommerce", index=False)
    orders_df.to_excel(writer, sheet_name="Orders", index=False)
    product_df.to_excel(writer, sheet_name="Products", index=False)
    print("\u2705 Data saved successfully as Excel!")
# Out:
# ✅ Data saved successfully as Excel!

# %% [markdown]
# #Download Excel file in local system

# %%
files.download("cleaned_ecommerce_data.xlsx")

# %% [markdown]
# #Further analysis is done in sql server by importing cleaned csv/excel data downloaded from python into SQL Server and Power Bi.

# %% [markdown]
# #Thank You
